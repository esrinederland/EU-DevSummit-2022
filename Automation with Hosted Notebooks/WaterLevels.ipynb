# %% [markdown]
# ## EU Dev Summit 2022
#
# ### Water Levels

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")

# %% [markdown]
# #### Import the script to run

# %%
import sys
sys.path.insert(0, "/arcgis/home")
import waterLevels

# %% [markdown]
# #### Run the script with the input parameter name.
# #### The parameter value is defined in the scheduled task

# %%
waterLevels.RunScript(location)
