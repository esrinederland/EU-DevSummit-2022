# %% [markdown]
# ## EU Dev Summit 2022
#
# ### Execute Notebook

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# /opt/conda/lib/python3.7/site-packages/arcgis/gis/__init__.py:575: UserWarning:
#
# You are logged on as mark_dev with an administrator role, proceed with caution.

# %% [markdown]
# #### Get the color parameter sent with the POST request

# %%
# Parameters
colorParam = "Color.YELLOW"

# %% [markdown]
# #### Update the color attribute of the (only) polygon in the layer

# %%
features = [
{
    'attributes': {
        'objectid': 1,
        'color': colorParam
    }
}]

fl = gis.content.get("efebd7de58af4bd6a3299d315132cd1a")
layer = fl.layers[0]
updated = layer.edit_features(updates=features)
